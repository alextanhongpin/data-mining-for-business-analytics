# %% [markdown]
# # Plotting Decision Boundary
#
#
# This example demonstrates how to plot the decision boundary for different classifier.

# %%
from sklearn.datasets import load_iris
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier

# %%
X, y = load_iris(return_X_y=True, as_frame=True)
X.shape, y.shape
# Out:
# ((150, 4), (150,))

# %%
X = X[["sepal length (cm)", "sepal width (cm)"]]
X.shape
# Out:
# (150, 2)

# %%
classifiers = [LinearRegression(), LogisticRegression(), DecisionTreeClassifier()]

for clf in classifiers:
    clf.fit(X, y)

    disp = DecisionBoundaryDisplay.from_estimator(clf, X, response_method="predict")
    disp.ax_.scatter(X.iloc[:, 0], X.iloc[:, 1], c=y, edgecolor="k")
    disp.ax_.set_title(clf.__class__.__name__)  # This returns the classifier name.
